# %%
from dotenv import load_dotenv
from pyflink.table.confluent import ConfluentSettings, ConfluentTools, ConfluentTableDescriptor
from pyflink.table import TableEnvironment, DataTypes, Schema
from pyflink.table.expressions import *
from pyflink.table import EnvironmentSettings, TableEnvironment
from pyflink.table.window import Tumble, Slide, Session
from pyflink.table.udf import udf

# %%
from dotenv import load_dotenv
load_dotenv(".env")
# Out:
# True

# %%
settings = ConfluentSettings.from_global_variables()

# settings = settings.in_streaming_mode()
env = TableEnvironment.create(settings)

# %%
# settings = ConfluentSettings.from_global_variables()
# settings.in_streaming_mode()
# # settings.in_batch_mode()
# env = TableEnvironment.create(settings)
# env.get_config().set("table.exec.source.cdc-events", "true")

# %%
env.list_catalogs() # list Kafka environments
# Out:
# ['default', 'examples', 'msds682']

# %%
env.use_catalog("msds682")

# %%
env.list_databases() # list Kafka clusters
# Out:
# ['INFORMATION_SCHEMA', 'msds682']

# %%
env.use_database("msds682")

# %%
env.list_tables() # list Kafka topics
# Out:
# ['system.usage', 'system.usage$errors']

# %%
table = env.from_path("`system.usage`")

# %%
ConfluentTools.print_changelog_limit(table, 10)
# Out:
# +----+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+-------------------------+
# | op |                            key |                             id |                      cpu_usage |                      cpu_stats |                   memory_usage |                      timestamp |                $rowtime |
# +----+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+-------------------------+
# | +I |                          x'31' |                              1 |                           26.8 | [19126.0, 220961.0, 1.76305... |                           73.3 |                   1.76361741E9 | 2025-11-19 21:43:28.973 |
# | +I |                          x'31' |                              1 |                           10.1 | [19126.0, 220961.0, 1.76305... |                           73.3 |                   1.76361741E9 | 2025-11-19 21:43:29.424 |
# | +I |                          x'31' |                              1 |                           22.4 | [27214.0, 266822.0, 1.76431... |                           74.6 |                   1.76361766E9 | 2025-11-19 21:48:33.383 |
# | +I |                          x'31' |                              1 |                           22.2 | [18638.0, 290688.0, 1.76432... |                           75.4 |                   1.76361766E9 | 2025-11-19 21:48:33.775 |
# | +I |                          x'31' |                              1 |                            0.0 | [15732.0, 264451.0, 1.76435... |                           74.5 |                   1.76361766E9 | 2025-11-19 21:48:43.942 |
# | +I |                          x'31' |                              1 |                           20.0 | [65919.0, 225233.0, 1.76691... |                           73.6 |                   1.76361843E9 | 2025-11-19 21:59:46.884 |
# | +I |                          x'31' |                              1 |                           32.8 | [12046.0, 237625.0, 1.76696... |                           74.5 |                   1.76361843E9 | 2025-11-19 21:59:53.630 |
# | +I |                          x'31' |                              1 |                           21.3 | [15539.0, 226969.0, 1.76697... |                           74.0 |                   1.76361843E9 | 2025-11-19 21:59:54.491 |
# | +I |                          x'31' |                              1 |                           27.9 | [14045.0, 228665.0, 1.76697... |                           74.1 |                   1.76361843E9 | 2025-11-19 21:59:54.675 |
# | +I |                          x'31' |                              1 |                           21.7 | [6202.0, 246787.0, 1.767053... |                           74.9 |                   1.76361843E9 | 2025-11-19 22:00:01.095 |
# +----+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+-------------------------+
# 10 rows in set

# %%
result = table.where(col("id")=='2').select(col("id"),col("memory_usage"), col("$rowtime").alias("rowtime"))
ConfluentTools.print_materialized_limit(result, 10)
# Out:
# +----+--------------+-------------------------+
# | id | memory_usage |                 rowtime |
# +----+--------------+-------------------------+
# |  2 |         75.4 | 2025-11-19 21:48:33.730 |
# |  2 |         74.5 | 2025-11-19 21:48:43.252 |
# |  2 |         74.5 | 2025-11-19 21:48:43.886 |
# |  2 |         72.7 | 2025-11-19 21:53:36.720 |
# |  2 |         72.7 | 2025-11-19 21:53:36.887 |
# |  2 |         72.7 | 2025-11-19 21:53:36.929 |
# |  2 |         74.2 | 2025-11-19 21:59:54.190 |
# |  2 |         74.1 | 2025-11-19 21:59:54.587 |
# |  2 |         74.9 | 2025-11-19 22:00:00.817 |
# |  2 |         74.9 | 2025-11-19 22:00:01.396 |
# +----+--------------+-------------------------+
# 10 rows in set

# %%
ConfluentTools.print_changelog_limit(result, 10)
# Out:
# +----+--------------------------------+--------------------------------+-------------------------+
# | op |                             id |                   memory_usage |                 rowtime |
# +----+--------------------------------+--------------------------------+-------------------------+
# | +I |                              2 |                           75.4 | 2025-11-19 21:48:33.730 |
# | +I |                              2 |                           74.5 | 2025-11-19 21:48:43.252 |
# | +I |                              2 |                           74.5 | 2025-11-19 21:48:43.886 |
# | +I |                              2 |                           72.7 | 2025-11-19 21:53:36.720 |
# | +I |                              2 |                           72.7 | 2025-11-19 21:53:36.887 |
# | +I |                              2 |                           72.7 | 2025-11-19 21:53:36.929 |
# | +I |                              2 |                           74.2 | 2025-11-19 21:59:54.190 |
# | +I |                              2 |                           74.1 | 2025-11-19 21:59:54.587 |
# | +I |                              2 |                           74.9 | 2025-11-19 22:00:00.817 |
# | +I |                              2 |                           74.9 | 2025-11-19 22:00:01.396 |
# +----+--------------------------------+--------------------------------+-------------------------+
# 10 rows in set

# %%
# aggregated = (
#     table
#     .window(Tumble.over(lit(1).second).on(col("rowtime")).alias("w"))
#     .group_by(col("id"), col("w"))
#     .select(
#         col("id"),
#         col("w").start.alias("window_start"),
#         col("w").end.alias("window_end"),
#         min(col("memory_usage")).alias("min_memory_usage")
#     ).limit(2)
# )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 9
#       1 aggregated = (
#       2     table
#       3     .window(Tumble.over(lit(1).second).on(col("rowtime")).alias("w"))
#       4     .group_by(col("id"), col("w"))
#       5     .select(
#       6         col("id"),
#       7         col("w").start.alias("window_start"),
#       8         col("w").end.alias("window_end"),
# ----> 9         min(col("memory_usage")).alias("min_memory_usage")
#      10     ).limit(2)
#      11 )
#
# File /opt/homebrew/anaconda3/envs/msds682-flink/lib/python3.11/site-packages/pyflink/table/expression.py:513, in Expression.__getitem__(self, index)
#     512 def __getitem__(self, index):
# --> 513     return self.at(index)
#
# File /opt/homebrew/anaconda3/envs/msds682-flink/lib/python3.11/site-packages/pyflink/table/expression.py:1456, in Expression.at(self, index)
#    1448 def at(self, index) -> 'Expression':
#    1449     """
#    1450     Accesses the element of an array or map based on a key or an index (starting at 1).
#    1451
#    (...)   1454     .. seealso:: :py:attr:`~Expression.cardinality`, :py:attr:`~Expression.element`
#    1455     """
# -> 1456     return _binary_op("at")(self, index)
#
# File /opt/homebrew/anaconda3/envs/msds682-flink/lib/python3.11/site-packages/pyflink/table/expression.py:278, in _binary_op.<locals>._(self, other)
#     276     return Expression(getattr(_get_java_expression(other, True), op_name)(self._j_expr))
#     277 else:
# --> 278     return Expression(getattr(self._j_expr, op_name)(_get_java_expression(other)))
#
# File /opt/homebrew/anaconda3/envs/msds682-flink/lib/python3.11/site-packages/py4j/java_gateway.py:1314, in JavaMember.__call__(self, *args)
#    1313 def __call__(self, *args):
# -> 1314     args_command, temp_args = self._build_args(*args)
#    1316     command = proto.CALL_COMMAND_NAME +\
#    1317         self.command_header +\
#    1318         args_command +\
#    1319         proto.END_COMMAND_PART
#    1321     answer = self.gateway_client.send_command(command)
#
# File /opt/homebrew/anaconda3/envs/msds682-flink/lib/python3.11/site-packages/py4j/java_gateway.py:1277, in JavaMember._build_args(self, *args)
#    1275 def _build_args(self, *args):
#    1276     if self.converters is not None and len(self.converters) > 0:
# -> 1277         (new_args, temp_args) = self._get_args(args)
#    1278     else:
#    1279         new_args = args
#
# File /opt/homebrew/anaconda3/envs/msds682-flink/lib/python3.11/site-packages/py4j/java_gateway.py:1263, in JavaMember._get_args(self, args)
#    1261 if not isinstance(arg, JavaObject):
#    1262     for converter in self.gateway_client.converters:
# -> 1263         if converter.can_convert(arg):
#    1264             temp_arg = converter.convert(arg, self.gateway_client)
#    1265             temp_args.append(temp_arg)
#
# File /opt/homebrew/anaconda3/envs/msds682-flink/lib/python3.11/site-packages/py4j/java_collections.py:517, in MapConverter.can_convert(self, object)
#     516 def can_convert(self, object):
# --> 517     return hasattr2(object, "keys") and hasattr2(object, "__getitem__")
#
# File /opt/homebrew/anaconda3/envs/msds682-flink/lib/python3.11/site-packages/py4j/compat.py:113, in hasattr2(obj, attr)
#     109     Empty = queue.Empty
#     112 if hasattr(inspect, "getattr_static"):
# --> 113     def hasattr2(obj, attr):
#     114         return bool(inspect.getattr_static(obj, attr, False))
#     115 else:
#
# KeyboardInterrupt:

# %%
table_rt = table.select(
        col("id"),
        col("memory_usage"),
        col("$rowtime").alias("rowtime")  # try metadata $rowtime first
    )

# %%
from pyflink.common.watermark_strategy import WatermarkStrategy
from datetime import timedelta

def extract_timestamp(event):
    # event is likely a Row or dictionary, depending on your source
    return event["$rowtime"]
